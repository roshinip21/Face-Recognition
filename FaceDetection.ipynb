# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install opencv-python imgbeddings psycopg2-binary
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 82.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.5 MB/s eta 0:00:00
# ...
#   Created wheel for imgbeddings: filename=imgbeddings-0.1.0-py3-none-any.whl size=9324 sha256=bc5f8300bf66f8e468dd9eb7a3e1332c59a6239a60c5412fdf6dd42f14ff0814
#   Stored in directory: /root/.cache/pip/wheels/4e/c9/9c/5f94fd783ce863540e5999f4bc2afd1501ddaea942ee6413fc
# Successfully built imgbeddings
# ...

# %%
pip install imgbeddings pillow
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for imgbeddings: filename=imgbeddings-0.1.0-py3-none-any.whl size=9324 sha256=fd65f06f9017a7c799ba9d562ceed1305ff0733ea55e40586591892a803d63b2
#   Stored in directory: /root/.cache/pip/wheels/4e/c9/9c/5f94fd783ce863540e5999f4bc2afd1501ddaea942ee6413fc
# Successfully built imgbeddings
# ...

# %% [markdown]
# For Multiple People in Image increase min-neighbours

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread('/content/AVG.webp')

if img is None:
    print("Error: Image not loaded. Please check the file path.")
else:
    # Convert image to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply histogram equalization for better contrast
    gray_img = cv2.equalizeHist(gray_img)

    # Load Haar Cascade
    haar_cascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

    if haar_cascade.empty():
      print("Error: Haar Cascade file not loaded!")

    else:
    # Detect faces with adjusted parameters
        faces_rect = haar_cascade.detectMultiScale(
        gray_img,
        scaleFactor=1.14,   # Smaller step between scales
        minNeighbors=5,    # Higher value reduces overlaps
        minSize=(30, 30)   # Minimum size of detected objects
    )

    print(f"Number of detected faces: {len(faces_rect)}")

    # Draw rectangles around detected faces
    for (x, y, w, h) in faces_rect:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the image with rectangles
    cv2_imshow(img)
# Out:
# Number of detected faces: 5
# <PIL.Image.Image image mode=RGB size=1600x800>
